# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
myFile = 'FilmLocations.csv'

# %%
myFile
# Out:
# 'FilmLocations.csv'

# %%
df = pd.read_csv(myFile, )

# %%
df.head()
# Out:
#   Title  Release Year                              Locations Fun Facts  \
# 0   180          2011      Epic Roasthouse (399 Embarcadero)       NaN
# 1   180          2011  Mason & California Streets (Nob Hill)       NaN
# 2   180          2011                    Justin Herman Plaza       NaN
# 3   180          2011                200 block Market Street       NaN
# 4   180          2011                              City Hall       NaN
#
#   Production Company Distributor  Director  \
# 0        SPI Cinemas         NaN  Jayendra
# 1        SPI Cinemas         NaN  Jayendra
# 2        SPI Cinemas         NaN  Jayendra
# 3        SPI Cinemas         NaN  Jayendra
# 4        SPI Cinemas         NaN  Jayendra
#
#                                               Writer   Actor 1       Actor 2  \
# 0  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# 1  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba   Siddarth  Nithya Menon
# ...

# %%
df.describe()
# Out:
#        Release Year
# count   1622.000000
# mean    1998.617756
# std       19.799099
# min     1915.000000
# 25%     1987.000000
# 50%     2004.000000
# 75%     2015.000000
# max     2018.000000

# %%
df.dtypes
# Out:
# Title                 object
# Release Year           int64
# Locations             object
# Fun Facts             object
# Production Company    object
# Distributor           object
# Director              object
# Writer                object
# Actor 1               object
# Actor 2               object
# Actor 3               object
# dtype: object

# %%
list(df[['Production Company']].groupby(df['Production Company']))
# Out:
# [('1492 Pictures',     Production Company
#   126      1492 Pictures
#   127      1492 Pictures
#   128      1492 Pictures
#   129      1492 Pictures
#   130      1492 Pictures
#   976      1492 Pictures
#   977      1492 Pictures
#   978      1492 Pictures
#   979      1492 Pictures
#   980      1492 Pictures
#   981      1492 Pictures
#   982      1492 Pictures
#   983      1492 Pictures
#   984      1492 Pictures
#   985      1492 Pictures
#   986      1492 Pictures
#   987      1492 Pictures
#   988      1492 Pictures
#   989      1492 Pictures
#   990      1492 Pictures), ('3 Ring Circus Films',       Production Company
#   369  3 Ring Circus Films
#   445  3 Ring Circus Films
#   446  3 Ring Circus Films), ('3311 Productions',     Production Company
#   140   3311 Productions), ('415 Productions',     Production Company
#   619    415 Productions
#   620    415 Productions
#   621    415 Productions), ('Alan Jacobs Productions',
#             Production Company
# ...

# %%
df[['Release Year', 'Title', 'Production Company', 'Actor 1', 'Actor 2', 'Actor 3', 'Director']].sort_values(by='Director' )
# Out:
#       Release Year                   Title  \
# 1505          2001     The Wedding Planner
# 1502          2001     The Wedding Planner
# 1503          2001     The Wedding Planner
# 1504          2001     The Wedding Planner
# 1506          2001     The Wedding Planner
# 1507          2001     The Wedding Planner
# 1508          2001     The Wedding Planner
# 1509          2001     The Wedding Planner
# 1427          1927         The Jazz Singer
# 975           1994      Nina Takes a Lover
# 730           2000          Just One Night
# 1161          1982          Shoot the Moon
# 1293          2015    Terminator - Genisys
# 1299          2015    Terminator - Genisys
# 1298          2015    Terminator - Genisys
# 1297          2015    Terminator - Genisys
# 1296          2015    Terminator - Genisys
# 1295          2015    Terminator - Genisys
# 1294          2015    Terminator - Genisys
# 1302          2015    Terminator - Genisys
# 1303          2015    Terminator - Genisys
# ...
